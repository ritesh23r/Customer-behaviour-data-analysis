# %% [markdown]
# <a href="https://colab.research.google.com/github/ritesh23r/Customer-behaviour-data-analysis/blob/main/Customer_Shopping_Behavior_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head(7)

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.columns

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
df = df.rename(columns ={ "purchase_amount_(usd)":"purchase_amount"})

# %%
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q= 4 , labels = labels)

# %%
frequency_mapping = {
    'Fortnightly' : 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
(df['discount_applied'] == df['promo_code_used']).all()

# %%
df = df.drop(columns= ['promo_code_used'], axis = 1)

# %%
# !pip install psycopg2-binary sqlalchemy

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://neondb_owner:npg_DyiQcG9O6AkH@ep-square-block-ap3kp93a-pooler.c-7.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require")

conn = engine.connect()

# %%
table_name = 'customer'
df.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 900
